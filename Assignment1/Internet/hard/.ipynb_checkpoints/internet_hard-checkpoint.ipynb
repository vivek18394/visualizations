# %%
# Libraries
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

import numpy as np
import pandas as pd

# Make data: I have 10 groups and some subgroups
share_df = pd.read_csv('share-of-individuals-using-the-internet.csv')

#Entity, code, year, percentage

share_df.shape #6056 X 4

#create a dataframe which has all countries and percentage in year 2016

share_2016_df = share_df[share_df['Year'] == 2016]

share_2016_df = share_2016_df[["Entity", "Individuals using the Internet (% of population)"]]

region = ["Pacific island small states", "South Asia"] #to be printed in outer donut

boolean_series = share_2016_df.Entity.isin(region)

share_2016_regions_df = share_2016_df[boolean_series]

group_size = share_2016_regions_df["Individuals using the Internet (% of population)"] #total number of internet users in south asia and pacific islands

print(group_size)

subregion_names = ['Afghanistan', 'India', 'Pakistan', 'Sri Lanka', 'Nepal', 'Bhutan', 'Maldives',
                   'Micronesia (country)', 'Fiji', 'French Polynesia',
                'Kiribati','Marshall Islands','New Zealand',
                'Solomon Islands','Tonga','Tuvalu','Vanuatu']#countries in s asia and PI

subregion_series = share_2016_df.Entity.isin(subregion_names)

share_2016_subregions_df = share_2016_df[subregion_series]#size of each country in s.asia and PI

subgroup_size = share_2016_subregions_df["Individuals using the Internet (% of population)"]
sub_size = list(subgroup_size)

print(share_2016_subregions_df)

# Create colors
a, b=[plt.cm.Blues, plt.cm.Reds]
 
# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=3.3, labels=region, colors=[a(0.8), b(0.90)] )
plt.setp( mypie, width=0.3, edgecolor='white')

# Second Ring (Inside)
sub_colors = [a(0.8),a(0.8),a(0.8), a(0.8),a(0.8),a(0.8),a(0.8),a(0.8), a(0.8),a(0.8), b(0.90) ,b(0.90),b(0.90), b(0.90), b(0.90), b(0.90), b(0.90),b(0.90), b(0.90), b(0.90)] 
print(type(sub_colors))
mypie2, _ = ax.pie(sub_size, radius=3.3-1.3, labels=subregion_names, colors=sub_colors)
plt.setp( mypie2, width=0.5, edgecolor='white')
plt.margins(0,0)
 
# show it
plt.show()
# Out:
# 4249    30.607213
# 5070    26.477736
# Name: Individuals using the Internet (% of population), dtype: float64
#                     Entity  Individuals using the Internet (% of population)
# 16             Afghanistan                                         10.595726
# 525                 Bhutan                                         41.772645
# 1832                  Fiji                                         46.506978
# 1930      French Polynesia                                         68.440419
# 2588                 India                                         29.547163
# 2883              Kiribati                                         13.700000
# 3458              Maldives                                         59.092590
# 3529      Marshall Islands                                         29.787779
# 3622  Micronesia (country)                                         33.352163
# 3914                 Nepal                                         19.688764
# 3990           New Zealand                                         88.470186
# 4271              Pakistan                                         15.514558
# 4995       Solomon Islands                                         11.000902
# 5180             Sri Lanka                                         32.051003
# 5561                 Tonga                                         39.950000
# 5667                Tuvalu                                         46.009152
# 5912               Vanuatu                                         24.000000
# <class 'list'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2bc5a5ab5445> in <module>
#      55 sub_colors = [a(0.8),a(0.8),a(0.8), a(0.8),a(0.8),a(0.8),a(0.8),a(0.8), a(0.8),a(0.8), b(0.90) ,b(0.90),b(0.90), b(0.90), b(0.90), b(0.90), b(0.90),b(0.90), b(0.90), b(0.90)]
#      56 print(type(sub_colors))
# ---> 57 mypie2, _ = ax.pie(sub_size, radius=3.3-1.3, labels=subregion_names, colors=sub_colors)
#      58 plt.setp( mypie2, width=0.5, edgecolor='white')
#      59 plt.margins(0,0)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2981             explode = [0] * len(x)
#    2982         if len(x) != len(labels):
# -> 2983             raise ValueError("'label' must be of length 'x'")
#    2984         if len(x) != len(explode):
#    2985             raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'
